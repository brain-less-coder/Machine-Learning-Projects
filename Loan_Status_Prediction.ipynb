# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/loan.csv")

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.isnull().sum()

# %%
df = pd.read_csv("/content/loan.csv")
df = df.dropna()
df.isnull().sum()

# %%
df.shape

# %%
df.replace({"Loan_Status":{'N':0,'Y':1}},inplace=True)

# %%
df.head()

# %%
df['Dependents'].value_counts()

# %%
df = df.replace(to_replace='3+',value = 4)

# %%
df['Dependents'].value_counts()

# %%
sns.countplot(x='Education',hue='Loan_Status',data=df)

# %%
sns.countplot(x='Credit_History',hue='Loan_Status',data=df)

# %%
sns.countplot(x='Married',hue='Loan_Status',data=df)

# %%
sns.countplot(x='Gender',hue='Loan_Status',data=df)

# %%
df.columns

# %%
df.head(2)

# %%
df.replace({"Gender":{'Male':0,'Female':1},"Property_Area":{'Rural':0,'Semiurban':1,'Urban':2},"Married":{'No':0,'Yes':1},"Education":{'Not Graduate':0,'Graduate':1},"Self_Employed":{'No':0,'Yes':1}},inplace=True)

# %%
df.head()

# %%
X = df.drop(columns=['Loan_ID','Loan_Status'],axis=1)
y = df['Loan_Status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify=y,random_state=42)

# %%
model = SVC(kernel = 'linear')

# %%
model.fit(X_train,y_train)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred)

# %%
accuracy

# %%
input_data = (0,1,2,1,1,5417,4196,267,360,1,2)
input_data_as_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
if(prediction[0] == 0):
  print('Loan is Not Approved')
else:
  print('Loan is Approved')
# Out:
# Loan is Approved
